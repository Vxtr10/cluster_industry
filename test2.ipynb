# %%
from datetime import datetime

# %%
import numpy as np

# %%
from yahooquery import Ticker
import pandas as pd

# Replace 'YOUR_STOCK_TICKER' with your specific stock ticker
ticker_symbol = 'AAPL'
stock = Ticker(ticker_symbol)
financial_data = stock.all_financial_data()
financial_data['date'] = pd.to_datetime(financial_data['asOfDate'])
fin_data = financial_data[financial_data['date'] > (pd.Timestamp.now() - pd.DateOffset(years=210))]
hist_data = stock.history(period="3y")
# Out:
# /Users/victor/anaconda3/lib/python3.11/site-packages/yahooquery/utils/__init__.py:1470: FutureWarning: 'S' is deprecated and will be removed in a future version. Please use 's' instead of 'S'.
#   has_live_indice = index_utc[-1] >= last_trade - pd.Timedelta(2, "S")
# /Users/victor/anaconda3/lib/python3.11/site-packages/yahooquery/ticker.py:1333: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["dividends"].fillna(0, inplace=True)

# %%
import yfinance as yf
import pandas as pd

# Initialize the Ticker
ticker_symbol = 'AAPL'
stock = yf.Ticker(ticker_symbol)

financials = stock.quarterly_financials

# %%
financials
# Out:
#                                                        2023-09-30  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                       0.149715
# Normalized EBITDA                                   30653000000.0
# Net Income From Continuing Operation Net Minori...  22956000000.0
# Reconciled Depreciation                              2653000000.0
# Reconciled Cost Of Revenue                          49071000000.0
# EBITDA                                              30653000000.0
# EBIT                                                28000000000.0
# Net Interest Income                                   -18000000.0
# Interest Expense                                     1002000000.0
# Interest Income                                       984000000.0
# Normalized Income                                   22956000000.0
# Net Income From Continuing And Discontinued Ope...  22956000000.0
# ...

# %%
fin_data['asOfDate'][0].date()
# Out:
# /var/folders/dr/g848f5b55mn9xp6p982hbg280000gn/T/ipykernel_61885/2140129016.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   fin_data['asOfDate'][0].date()
# datetime.date(2021, 9, 30)

# %%
hist_data.iloc[0].name
# Out:
# ('AAPL', datetime.date(2021, 1, 25))

# %%
hist_data.loc[(('AAPL'),fin_data['asOfDate'][0].date())]['close']
hist_data.loc[(('AAPL'),fin_data['asOfDate'][1].date())]['close']
hist_data.loc[(('AAPL'),fin_data['asOfDate'][2].date())]['close']
hist_data.loc[(('AAPL'),fin_data['asOfDate'][3].date())]['close']
hist_data.loc[(('AAPL'),fin_data['asOfDate'][4].date())]['close']
hist_data.loc[(('AAPL'),fin_data['asOfDate'][5].date())]['close']
hist_data.loc[(('AAPL'),fin_data['asOfDate'][6].date())]['close']
hist_data.loc[(('AAPL'),fin_data['asOfDate'][7].date())]['close']
# Out:
# /var/folders/dr/g848f5b55mn9xp6p982hbg280000gn/T/ipykernel_61885/2946619184.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hist_data.loc[(('AAPL'),fin_data['asOfDate'][0].date())]['close']
# /var/folders/dr/g848f5b55mn9xp6p982hbg280000gn/T/ipykernel_61885/2946619184.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hist_data.loc[(('AAPL'),fin_data['asOfDate'][1].date())]['close']
# ...

# %%
import pandas as pd

mkt_cap = close_price*fin_data['DilutedAverageShares']
print(mkt_cap)
total_debt = fin_data['TotalDebt']
cash_eqv = fin_data['CashAndCashEquivalents']
fin_data['P/E'] = fin_data['close_price'] / fin_data['BasicEPS']
fin_data['P/S'] = mkt_cap / fin_data['TotalRevenue']
fin_data['P/B'] = mkt_cap / fin_data['TotalEquityGrossMinorityInterest']
fin_data['EV/EBITDA'] = (mkt_cap + total_debt - cash_eqv) / fin_data['EBITDA']
fin_data['EV/FCF'] = (mkt_cap + total_debt - cash_eqv) / fin_data['FreeCashFlow']
fin_data['Current Ratio'] = fin_data['CurrentAssets'] / fin_data['CurrentLiabilities']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 3
#       1 import pandas as pd
# ...
